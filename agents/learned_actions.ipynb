# %% [markdown]
# ## Installations and Imports

# %%
# No need to run this cell if you are not using Google Drive and you have all the files in the same folder as this notebook
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !sudo add-apt-repository -y ppa:openjdk-r/ppa
# !sudo apt-get purge openjdk-*
# !sudo apt-get install openjdk-8-jdk
# !sudo apt-get install xvfb xserver-xephyr vnc4server python-opengl ffmpeg

# %%
# %%capture
# !pip install --upgrade 'setuptools==57.5.0'
# !pip install 'gym==0.19.0'
# !pip install --upgrade wheel==0.38.4

# %%
# %%capture
# !pip install --upgrade 'minerl==0.4.4'
# !pip install pyvirtualdisplay

# !pip install scikit-learn
# !pip install -U colabgymrender

# %%
# %%capture
# !apt-get install xorg openbox
# !apt-get install xvfb

# %%
import random
import numpy as np
import pandas as pd
import torch as th
from torch import nn
import gym
import minerl
import torch
from tqdm.notebook import tqdm
from colabgymrender.recorder import Recorder
from pyvirtualdisplay import Display
from sklearn.cluster import KMeans
import logging
from sklearn.cluster import DBSCAN
from sklearn.metrics import pairwise_distances
import matplotlib.pyplot as plt
import json
from time import time
import pickle

logging.disable(logging.ERROR) # reduce clutter, remove if something doesn't work to see the error logs.
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/logger.py:34: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))

# %%
minerl.data.download(directory='data', environment='MineRLObtainIronPickaxe-v0');
# Out:
# Download: https://minerl.s3.amazonaws.com/v4/MineRLObtainIronPickaxe-v0.tar: 100%|██████████| 2802.0/2801.89952 [02:55<00:00, 16.00MB/s]

# %%
data=minerl.data.make("MineRLObtainIronPickaxe-v0")

# %%
# run only once!!! ## starts the virtual display
display = Display(visible=0, size=(400, 300))
display.start();

# %% [markdown]
# ## Load Preprocessed Data

# %%
# loads the saved json files, change the paths to the location of the files
with open('/content/drive/MyDrive/minecraft proj/state_to_transition.json', 'r') as f:
   state_to_actions_without_clustering = json.load(f)

with open('/content/drive/MyDrive/minecraft proj/pov_cluster_to_transition_with_30K_pov.json', 'r') as f:
    pov_to_actions = json.load(f)

# %%
def load_pov_clustering(model_fn):
    """
    Loads the pov clustering model
    
    Args:
        model_fn: file name of the stored model
    """
    clustering = pickle.load(open(model_fn, "rb"))
    return clustering

# %%
# !unzip '/content/drive/MyDrive/minecraft proj/KNN_povs_30K.zip'  # change the path to your own
clustering = load_pov_clustering('KNN_povs.pkl')
# Out:
# Archive:  /content/drive/MyDrive/minecraft proj/KNN_povs_30K.zip
#   inflating: KNN_povs.pkl

# %% [markdown]
# ## Learned-Actions Algorithm

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def update_stage(state, stage):
  """Check the inventory and updates the agent's stage in the game
  
  Args:
      state: the agent's state in the game
      stage: game's stage, derived from agent's inventory

  Return:
      tuple (stage, is_changed)
  """
  if stage == 0:
    logs = int(state['inventory']['log'])
    if logs > 0:
      print("GOT", logs, "logs")
    if logs >= 3:
      return (1, True)
  
  elif stage == 1:
    cobblestones = int(state['inventory']['cobblestone'])
    if logs > 0:
      print("GOT", cobblestones, "cobblestones")
    if cobblestones >= 11:
      return (2, True)
  
  else: # stage == 2:
    iron_ores = int(state['inventory']['iron_ore'])
    coals = int(state['inventory']['coal'])
    if iron_ores >= 3 and coals >= 3:
      return (3, True)
  
  return (stage, False)

# %%
def predict_pov_cluster(model, pov):
    """
    Predict cluster label of a single POV
    
    Args:        
        model: instance of the clustering model
        pov: 64*64*3 array
    """
    # Normalize the new pov
    pov_normalized = pov / 255.0  
    # Predict the label of the new pov
    label = model.predict(pov_normalized.reshape(1, -1))
    return label[0]

# %%
def get_relevant_actions(model, state):
    """
    Returns the relevant actions to the agent based on its pov. If not possible, use the current state including what it is holding in hand and its inventory. 

    Args:
        model: instance of the clustering model
        state: the agent's current state
    Return:
        actions: list of actions 
    """
    # Get the pov cluster by the clustering model
    current_pov = np.array(state['pov'])
    pov_cluster = predict_pov_cluster(model, current_pov)

    # If possible, get the actions by the relevant pov cluster
    pov_cluster_str = str(pov_cluster)
    if pov_cluster_str != '-1' and pov_cluster_str in pov_to_actions:
      actions = pov_to_actions[pov_cluster_str]
      actions = [lst for lst in actions if lst]
      return actions

    # If pov cluster is not valid, get the actions by the current state including what is in hand and the inventory
    state_small = {'equipped_items.mainhand.type': state['equipped_items']['mainhand']['type'], 
                  'inventory': {key:int(val) for key,val in state['inventory'].items()}}
    key_state = json.dumps(state_small)
    actions = state_to_actions_without_clustering.get(key_state, None)

    if actions:
      actions = [lst for lst in actions if lst]

    return actions

# %% [markdown]
# ## Test

# %%
def str_to_act(action, value, env):
    """Reutrn the action should be done in the expected format"""
    act = env.action_space.noop()
    act[action] = value
    return act

# %%
def act(state, stage, env):
    """Performs a single step for the agent in the game.
    Choose the next action from the distribution of the actions of other agents performed from a state similar to the agent's current state.
    
    Args:
        state: the agent's state in the game
        stage: game's stage, derived from agent's inventory
        env: game environment
    Return:
        (obs, rewards, done, stage, steps): data of next state
    """
    actions = get_relevant_actions(clustering, state)
    
    if actions is None or actions == []:
      action = env.action_space.sample()
      obs, rewards, done, _ = env.step(action) # Take a random action
      steps = 1
      return obs, rewards, done, stage, steps
    
    steps = 0
    rewards = 0
    chosen_action = random.choice(actions) # [[a, 1], [b, 2]]
    for a in chosen_action:
      action, value = tuple(a)
      obs, reward, done, _ = env.step(str_to_act(action, value, env))
      steps += 1
      rewards += reward
      stage, is_changed = update_stage(state, stage)
      if is_changed:
        print(f"stage {stage}")

      if done:
        return obs, rewards, done, stage, steps

    return obs, rewards, done, stage, steps

# %%
def test_model(episodes, env):
  stats = {'runtime': [], 'reward': [], 'reward_at': []}

  for i in range(1, episodes + 1):
    print(f"Episode {i}")
    start = time()
    obs = env.reset()
    done = False
    total_reward = 0
    stage = 0
    total_steps = 0
    reward_at = []
    j = 0
    
    while not done:
      obs, reward, done, stage, steps = act(obs, stage, env)
      total_steps += steps
      total_reward += reward
      if reward > 0:
        reward_at.append((total_steps, reward))
      if total_steps >= 100 * j:
        j += 1
        print(total_steps)
      if done:
        break
    
    stats['runtime'].append(time() - start)
    stats['reward'].append(total_reward)
    stats['reward_at'].append(reward_at)

  return stats

# %%
# stops the virtual display and restarts it (run if display crashed or stopped working)
# display.stop()
# !rm -rf /content/logs
# !rm -rf /content/video

# display = Display(visible=0, size=(400, 300))
# display.start();

# %%
env = gym.make('MineRLObtainIronPickaxe-v0')
env = Recorder(env, './video', fps=60)

# %%
# save the stats of the agent's performance
episodes = 2
stats = test_model(episodes, env)
with open(f'stats_learned_actions.json', 'w') as outfile:
    json.dump(stats, outfile)
# Out:
# Episode 1
# 1
# 100
# 200
# 300
# 400
# 500
# 601
# 700
# 800
# 900
# 1000
# 1103
# 1201
# 1301
# 1401
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3001
# 3100
# 3200
# 3300
# 3401
# 3500
# 3600
# 3700
# 3800
# 3900
# 4001
# 4100
# 4200
# 4302
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5001
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# Episode 2
# 1
# 100
# 200
# 300
# 400
# 500
# 600
# 701

# %% [markdown]
# ## POV Actions Distribution

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager
font_prop = font_manager.FontProperties(family='fantasy')

with open('/content/drive/MyDrive/minecraft proj/pov_to_actions_counter.json', 'r') as f: # load the needed json file, change the path to your own
    pov_to_actions_counter = json.load(f)

# %%
list(pov_to_actions_counter.items())[0]
# Out:
# ('0',
#  {'forward': 255824,
#   'back': 13385,
#   'left': 33436,
#   'right': 32964,
#   'attack': 495180,
#   'jump': 54623,
#   'craftplanks': 493,
#   'craftcrafting_table': 201,
#   'placecrafting_table': 536,
#   'craftstick': 451,
#   'nearbyCraftwooden_pickaxe': 184,
#   'equipwooden_pickaxe': 359,
#   'nearbyCraftfurnace': 198,
#   'nearbyCraftstone_pickaxe': 254,
#   'equipstone_pickaxe': 367,
#   'placefurnace': 230,
#   'nearbySmeltiron_ingot': 232,
#   'nearbyCraftiron_pickaxe': 164,
#   'sprint': 40447,
#   'sneak': 17563,
#   'nearbyCraftwooden_axe': 17,
#   'equipwooden_axe': 94,
#   'crafttorch': 134,
#   'placetorch': 1054,
#   'placestone': 152,
#   'placedirt': 257,
#   'nearbyCraftstone_axe': 8,
#   'equipstone_axe': 29,
#   'nearbySmeltcoal': 23,
#   'placecobblestone': 818,
#   'equipiron_pickaxe': 2})

# %%
# remove uninformative clusters
del pov_to_actions_counter['-1']
del pov_to_actions_counter['0']

# %%
# plot the distribution of action for each pov cluster
num_keys = len(pov_to_actions_counter.keys())
fig, axs = plt.subplots(num_keys, 1, figsize=(5, 5*num_keys))

for i, (pov_cluster, value_dict) in enumerate(pov_to_actions_counter.items()):

    df = pd.DataFrame.from_dict(value_dict, orient='index', columns=['Count'])
    df.sort_values('Count', ascending=False, inplace=True)
  
    ax = axs[i]
    ax.bar(df.index, df['Count'], width=0.4, color='#169c9d')
    ax.set_title(f'POV cluster {pov_cluster}', fontproperties=font_prop, size=12)
    ax.set_xlabel('Action', fontproperties=font_prop, size=10)
    ax.set_ylabel('Count', fontproperties=font_prop, size=10)
    ax.tick_params(axis='x', rotation=90)
    
    ax.set_facecolor('#EAEAF2')
    ax.grid(True)
    ax.set_axisbelow(True)

plt.tight_layout()
plt.show()

# %%
# create converted dictionary
action_to_pov_distribution = {}

for pov_cluster, value_dict in pov_to_actions_counter.items():
    
    for action, count in value_dict.items():
        if action not in action_to_pov_distribution:
            action_to_pov_distribution[action] = {}
        
        action_to_pov_distribution[action][pov_cluster] = count

# %%
# plot the distribution of pov clusters for each action
num_keys = len(action_to_pov_distribution.keys())
fig, axs = plt.subplots(num_keys, 1, figsize=(8, 5*num_keys))

for i, (action_name, value_dict) in enumerate(action_to_pov_distribution.items()):

    df = pd.DataFrame.from_dict(value_dict, orient='index', columns=['Count'])
    df.sort_values('Count', ascending=False, inplace=True)
  
    ax = axs[i]
    ax.bar(df.index, df['Count'], width=0.4, color='#169c9d')
    ax.set_title(f'Action: {action_name}', fontproperties=font_prop, size=12)
    ax.set_xlabel('POV cluster', fontproperties=font_prop, size=10)
    ax.set_ylabel('Count', fontproperties=font_prop, size=10)
    ax.tick_params(axis='x', rotation=90)
    ax.set_yscale('log')

    ax.set_facecolor('#EAEAF2')
    ax.grid(True)
    ax.set_axisbelow(True)

plt.tight_layout()
plt.show()
